# %%
import pandas as pd

# %%
data = pd.read_csv('patient_info_mdacc.csv')
data.head()
# Out:
#    Dummy ID  Age at Diagnosis (Calculated)  Gender                    Race  \
# 0     10183                      45.950000    Male         White/Caucasion
# 1         7                      65.369444    Male         White/Caucasion
# 2        13                      54.200000    Male  African American/Black
# 3       175                      75.555556    Male         White/Caucasion
# 4       245                      68.805556  Female         White/Caucasion
#
#   Tm Laterality (R/L)  \
# 0           Bilateral
# 1           Bilateral
# 2           Bilateral
# 3           Bilateral
# 4           Bilateral
#
#   Tumor subsite (BOT/Tonsil/Soft Palate/Pharyngeal wall/GPS/NOS)  \
# 0                                             Tonsil
# 1                                                BOT
# 2                                                NOS
# 3                                                BOT
# 4                                                NOS
#
#   HPV/P16 status T-category  \
# ...

# %%
new_data = data[['Dummy ID',]]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 639      Male
# 640      Male
# 641      Male
# 642      Male
# 643      Male
# Name: Gender, Length: 644, dtype: object
